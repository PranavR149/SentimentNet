# %%
import pandas as pd
import re
import nltk
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# 2024-05-04 11:44:58.030803: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-04 11:44:58.031053: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-04 11:44:58.032801: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-04 11:44:58.055881: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 11:44:58.683325: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
# # Loading the dataset (using the downloaded file)
# path = "/content/drive/MyDrive/Colab Notebooks/DATA255_Assignment/IMDB_Dataset.csv"
# df = pd.read_csv(path)

# %%
df= pd.read_csv("IMDB_Dataset.csv")
df.head()
# Out:
#                                               review  sentiment
# 0  Once again Mr. Costner has dragged out a movie...          0
# 1  This is an example of why the majority of acti...          0
# 2  First of all I hate those moronic rappers, who...          0
# 3  Not even the Beatles could write songs everyon...          0
# 4  Brass pictures (movies is not a fitting word f...          0

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
##cleaning up the text
stopWords = set(nltk.corpus.stopwords.words("english"))
def CleanText(text):
    text = text.lower()
    text = re.sub("[^a-z]", " ", text)
    words = [word for word in text.split() if word not in stopWords]
    text = " ".join(words)
    return text

df["review"]=df.apply(lambda row: CleanText(row["review"]), axis=1)
Data = df.review
labels = df.sentiment

# %%
### converting 1000 most frequent words to integer
frequentWord = 10000
tokenizer = Tokenizer(num_words=frequentWord)

tokenizer.fit_on_texts(Data)

IntegerizedData = pd.Series(tokenizer.texts_to_sequences(Data))
IntegerizedData.head()
# Out:
# 0    [315, 6873, 3237, 2, 117, 996, 1569, 1033, 117...
# 1    [342, 2080, 100, 30, 3711, 232, 11, 66, 165, 5...
# 2    [20, 595, 4986, 24, 8579, 369, 844, 7247, 2536...
# 3    [8, 5767, 24, 749, 582, 180, 304, 147, 2329, 2...
# 4    [8836, 1155, 25, 3325, 521, 11, 535, 9224, 920...
# dtype: object

# %%
### You can convert the sequences back to the string
tokenizer.sequences_to_texts(IntegerizedData[0:1])
# Out:
# ['mr costner dragged movie far longer necessary aside terrific sea rescue sequences care characters us ghosts closet costner character realized early forgotten much later time care character really care cocky ashton kutcher problem comes kid thinks better anyone else around shows signs closet appears winning costner finally well past half way point stinker costner tells us kutcher ghosts told kutcher driven best prior magic could keep turning hour']

# %%
DataLength=IntegerizedData.apply(lambda x: len(x))
DataLength.describe()
# Out:
# count    50000.000000
# mean       110.157100
# std         81.213625
# min          3.000000
# 25%         60.000000
# 50%         83.000000
# 75%        135.000000
# max       1104.000000
# dtype: float64

# %% [markdown]
# The average length of reviews is 110, the shortest review length is 3 and the longest is 1104.
#
# Therefore we need to pad the sequences to equal length.
#
# The following padding function performs zero padding if the length of a sequence is less than the threshold and truncate the ones which are longer than threshold to the threshold.  We choose the threshold to be 256.

# %%
#zero padding
IntegerizedData= pad_sequences(IntegerizedData, maxlen=256)

# %%
IntegerizedData
# Out:
# array([[   0,    0,    0, ...,  269, 1456,  397],
#        [   0,    0,    0, ...,  363,    3,   80],
#        [   0,    0,    0, ...,   54,   57,   76],
#        ...,
#        [   0,    0,    0, ...,  973,   99, 9907],
#        [   0,    0,    0, ..., 8508, 3506,   13],
#        [   0,    0,    0, ...,   11, 2263,   23]], dtype=int32)

# %%
x_train_val,x_test,y_train_val,y_test = train_test_split(IntegerizedData,labels,stratify=labels,test_size=0.20, random_state=42)
x_train,x_val,y_train,y_val = train_test_split(x_train_val,y_train_val,stratify=y_train_val,test_size=0.10, random_state=42)

# %%
type(x_val)
# Out:
# numpy.ndarray

# %%
print(y_train.shape,y_val.shape,y_test.shape)
# Out:
# (36000,) (4000,) (10000,)

# %% [markdown]
# ## now you have your training, validation and test set as numpy arrays, you can implement the networks

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset
import tensorflow as tf
import torch
from torch.utils.data import TensorDataset, DataLoader
import time

# %%
# Define the LSTM model
class LSTMModel(nn.Module):
    def __init__(self, embedding_dim, vocab_size, hidden_dim):
        super(LSTMModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        embeds = self.embedding(x)
        lstm_out, _ = self.lstm(embeds)
        lstm_out = lstm_out[:, -1, :]  # Take the output of the last time step
        out = self.fc(lstm_out)
        out = self.sigmoid(out)
        return out.squeeze()

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Convert data to PyTorch tensors and move to GPU
x_train_tensor = torch.tensor(x_train).long().to(device)
y_train_tensor = torch.tensor(y_train.values).float().to(device)
x_val_tensor = torch.tensor(x_val).long().to(device)
y_val_tensor = torch.tensor(y_val.values).float().to(device)
x_test_tensor = torch.tensor(x_test).long().to(device)

# Create DataLoader for training and validation sets
train_dataset = TensorDataset(x_train_tensor, y_train_tensor.unsqueeze(1))  # Add unsqueeze(1) to add a singleton dimension
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True)
val_dataset = TensorDataset(x_val_tensor, y_val_tensor.unsqueeze(1))  # Add unsqueeze(1) to add a singleton dimension
val_loader = DataLoader(val_dataset, batch_size=512)

# Hyperparameters
embedding_dim = 64
hidden_dim = 64
learning_rate = 0.0001
num_epochs = 80

# Instantiate the model and move it to GPU
model = LSTMModel(vocab_size=frequentWord, embedding_dim=embedding_dim, hidden_dim=hidden_dim).to(device)

# Define loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)  # Removed weight decay

# Training loop
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(num_epochs):
    start_time = time.time()  # Record start time for the epoch

    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Move batch to GPU
        optimizer.zero_grad()
        outputs = model(inputs)
        labels = labels.view(-1)  # Ensure labels have the correct shape
        loss = criterion(outputs, labels.float())  # Cast labels to float
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)

        predicted = torch.round(outputs)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)
    train_accuracy = correct_train / total_train
    train_accuracies.append(train_accuracy)

    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move batch to GPU
            outputs = model(inputs)
            labels = labels.view(-1)  # Ensure labels have the correct shape
            loss = criterion(outputs, labels.float())  # Cast labels to float
            val_loss += loss.item() * inputs.size(0)

            predicted = torch.round(outputs)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss /= len(val_loader.dataset)
    val_losses.append(val_loss)
    val_accuracy = correct_val / total_val
    val_accuracies.append(val_accuracy)

    epoch_time = time.time() - start_time  # Calculate time taken for the epoch
    print(f'Epoch {epoch+1}/{num_epochs}, Time: {epoch_time:.2f}s, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Accuracy: {val_accuracy:.4f}')


# Plotting train and validation losses
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting train and validation accuracies
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluation on test set
model.eval()
with torch.no_grad():
    outputs = model(x_test_tensor)
    y_pred = torch.round(outputs).cpu().numpy()  # Move predictions to CPU for numpy conversion

# Calculate test accuracy
test_accuracy = np.mean(y_pred == y_test.values)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/80, Time: 1.23s, Train Loss: 0.6933, Val Loss: 0.6908, Train Accuracy: 0.5036, Val Accuracy: 0.5285
# Epoch 2/80, Time: 0.41s, Train Loss: 0.6891, Val Loss: 0.6874, Train Accuracy: 0.5414, Val Accuracy: 0.5595
# Epoch 3/80, Time: 0.40s, Train Loss: 0.6847, Val Loss: 0.6834, Train Accuracy: 0.5690, Val Accuracy: 0.5743
# Epoch 4/80, Time: 0.42s, Train Loss: 0.6786, Val Loss: 0.6769, Train Accuracy: 0.5886, Val Accuracy: 0.5900
# Epoch 5/80, Time: 0.40s, Train Loss: 0.6667, Val Loss: 0.6587, Train Accuracy: 0.6119, Val Accuracy: 0.6190
# Epoch 6/80, Time: 0.40s, Train Loss: 0.6166, Val Loss: 0.5978, Train Accuracy: 0.6675, Val Accuracy: 0.6817
# Epoch 7/80, Time: 0.41s, Train Loss: 0.5745, Val Loss: 0.5737, Train Accuracy: 0.7096, Val Accuracy: 0.7020
# Epoch 8/80, Time: 0.60s, Train Loss: 0.5473, Val Loss: 0.5430, Train Accuracy: 0.7323, Val Accuracy: 0.7300
# Epoch 9/80, Time: 0.40s, Train Loss: 0.5203, Val Loss: 0.5191, Train Accuracy: 0.7499, Val Accuracy: 0.7485
# Epoch 10/80, Time: 0.40s, Train Loss: 0.4983, Val Loss: 0.4976, Train Accuracy: 0.7643, Val Accuracy: 0.7642
# Epoch 11/80, Time: 0.42s, Train Loss: 0.4777, Val Loss: 0.4787, Train Accuracy: 0.7784, Val Accuracy: 0.7802
# Epoch 12/80, Time: 0.43s, Train Loss: 0.4601, Val Loss: 0.4624, Train Accuracy: 0.7906, Val Accuracy: 0.7877
# Epoch 13/80, Time: 0.56s, Train Loss: 0.4419, Val Loss: 0.4488, Train Accuracy: 0.8016, Val Accuracy: 0.7975
# Epoch 14/80, Time: 0.57s, Train Loss: 0.4263, Val Loss: 0.4363, Train Accuracy: 0.8126, Val Accuracy: 0.8060
# Epoch 15/80, Time: 0.58s, Train Loss: 0.4133, Val Loss: 0.4248, Train Accuracy: 0.8208, Val Accuracy: 0.8140
# Epoch 16/80, Time: 0.77s, Train Loss: 0.4004, Val Loss: 0.4159, Train Accuracy: 0.8277, Val Accuracy: 0.8183
# Epoch 17/80, Time: 0.62s, Train Loss: 0.3890, Val Loss: 0.4092, Train Accuracy: 0.8332, Val Accuracy: 0.8235
# Epoch 18/80, Time: 0.57s, Train Loss: 0.3777, Val Loss: 0.4017, Train Accuracy: 0.8391, Val Accuracy: 0.8295
# Epoch 19/80, Time: 0.55s, Train Loss: 0.3683, Val Loss: 0.3959, Train Accuracy: 0.8431, Val Accuracy: 0.8300
# Epoch 20/80, Time: 0.64s, Train Loss: 0.3595, Val Loss: 0.3883, Train Accuracy: 0.8482, Val Accuracy: 0.8333
# Epoch 21/80, Time: 0.57s, Train Loss: 0.3512, Val Loss: 0.3840, Train Accuracy: 0.8528, Val Accuracy: 0.8385
# Epoch 22/80, Time: 0.56s, Train Loss: 0.3431, Val Loss: 0.3809, Train Accuracy: 0.8562, Val Accuracy: 0.8383
# Epoch 23/80, Time: 0.58s, Train Loss: 0.3369, Val Loss: 0.3745, Train Accuracy: 0.8597, Val Accuracy: 0.8417
# Epoch 24/80, Time: 0.56s, Train Loss: 0.3294, Val Loss: 0.3719, Train Accuracy: 0.8637, Val Accuracy: 0.8438
# Epoch 25/80, Time: 0.57s, Train Loss: 0.3229, Val Loss: 0.3719, Train Accuracy: 0.8679, Val Accuracy: 0.8450
# Epoch 26/80, Time: 0.55s, Train Loss: 0.3163, Val Loss: 0.3639, Train Accuracy: 0.8704, Val Accuracy: 0.8470
# Epoch 27/80, Time: 0.57s, Train Loss: 0.3103, Val Loss: 0.3601, Train Accuracy: 0.8725, Val Accuracy: 0.8482
# Epoch 28/80, Time: 0.57s, Train Loss: 0.3045, Val Loss: 0.3562, Train Accuracy: 0.8760, Val Accuracy: 0.8520
# Epoch 29/80, Time: 0.56s, Train Loss: 0.2987, Val Loss: 0.3571, Train Accuracy: 0.8786, Val Accuracy: 0.8522
# Epoch 30/80, Time: 0.57s, Train Loss: 0.2935, Val Loss: 0.3561, Train Accuracy: 0.8814, Val Accuracy: 0.8550
# Epoch 31/80, Time: 0.55s, Train Loss: 0.2901, Val Loss: 0.3525, Train Accuracy: 0.8823, Val Accuracy: 0.8540
# Epoch 32/80, Time: 0.55s, Train Loss: 0.2829, Val Loss: 0.3478, Train Accuracy: 0.8848, Val Accuracy: 0.8568
# Epoch 33/80, Time: 0.80s, Train Loss: 0.2778, Val Loss: 0.3499, Train Accuracy: 0.8888, Val Accuracy: 0.8575
# Epoch 34/80, Time: 0.59s, Train Loss: 0.2732, Val Loss: 0.3437, Train Accuracy: 0.8904, Val Accuracy: 0.8595
# Epoch 35/80, Time: 0.57s, Train Loss: 0.2688, Val Loss: 0.3398, Train Accuracy: 0.8919, Val Accuracy: 0.8610
# Epoch 36/80, Time: 0.56s, Train Loss: 0.2648, Val Loss: 0.3399, Train Accuracy: 0.8945, Val Accuracy: 0.8598
# Epoch 37/80, Time: 0.57s, Train Loss: 0.2607, Val Loss: 0.3390, Train Accuracy: 0.8966, Val Accuracy: 0.8608
# Epoch 38/80, Time: 0.56s, Train Loss: 0.2561, Val Loss: 0.3391, Train Accuracy: 0.8983, Val Accuracy: 0.8652
# Epoch 39/80, Time: 0.55s, Train Loss: 0.2520, Val Loss: 0.3381, Train Accuracy: 0.9012, Val Accuracy: 0.8658
# Epoch 40/80, Time: 0.55s, Train Loss: 0.2477, Val Loss: 0.3309, Train Accuracy: 0.9031, Val Accuracy: 0.8640
# Epoch 41/80, Time: 0.57s, Train Loss: 0.2450, Val Loss: 0.3392, Train Accuracy: 0.9038, Val Accuracy: 0.8668
# Epoch 42/80, Time: 0.59s, Train Loss: 0.2406, Val Loss: 0.3379, Train Accuracy: 0.9057, Val Accuracy: 0.8678
# Epoch 43/80, Time: 0.58s, Train Loss: 0.2371, Val Loss: 0.3321, Train Accuracy: 0.9074, Val Accuracy: 0.8670
# Epoch 44/80, Time: 0.58s, Train Loss: 0.2329, Val Loss: 0.3365, Train Accuracy: 0.9097, Val Accuracy: 0.8718
# Epoch 45/80, Time: 0.57s, Train Loss: 0.2292, Val Loss: 0.3298, Train Accuracy: 0.9113, Val Accuracy: 0.8675
# Epoch 46/80, Time: 0.58s, Train Loss: 0.2253, Val Loss: 0.3371, Train Accuracy: 0.9120, Val Accuracy: 0.8690
# Epoch 47/80, Time: 0.58s, Train Loss: 0.2221, Val Loss: 0.3377, Train Accuracy: 0.9146, Val Accuracy: 0.8690
# Epoch 48/80, Time: 0.58s, Train Loss: 0.2186, Val Loss: 0.3356, Train Accuracy: 0.9158, Val Accuracy: 0.8700
# Epoch 49/80, Time: 0.56s, Train Loss: 0.2150, Val Loss: 0.3351, Train Accuracy: 0.9183, Val Accuracy: 0.8718
# Epoch 50/80, Time: 0.82s, Train Loss: 0.2118, Val Loss: 0.3356, Train Accuracy: 0.9190, Val Accuracy: 0.8708
# Epoch 51/80, Time: 0.57s, Train Loss: 0.2086, Val Loss: 0.3255, Train Accuracy: 0.9211, Val Accuracy: 0.8700
# Epoch 52/80, Time: 0.58s, Train Loss: 0.2058, Val Loss: 0.3348, Train Accuracy: 0.9219, Val Accuracy: 0.8708
# Epoch 53/80, Time: 0.57s, Train Loss: 0.2030, Val Loss: 0.3336, Train Accuracy: 0.9230, Val Accuracy: 0.8710
# Epoch 54/80, Time: 0.56s, Train Loss: 0.2002, Val Loss: 0.3335, Train Accuracy: 0.9245, Val Accuracy: 0.8722
# Epoch 55/80, Time: 0.55s, Train Loss: 0.1966, Val Loss: 0.3386, Train Accuracy: 0.9269, Val Accuracy: 0.8722
# Epoch 56/80, Time: 0.57s, Train Loss: 0.1936, Val Loss: 0.3328, Train Accuracy: 0.9273, Val Accuracy: 0.8722
# Epoch 57/80, Time: 0.57s, Train Loss: 0.1904, Val Loss: 0.3351, Train Accuracy: 0.9295, Val Accuracy: 0.8735
# Epoch 58/80, Time: 0.79s, Train Loss: 0.1876, Val Loss: 0.3372, Train Accuracy: 0.9303, Val Accuracy: 0.8728
# Epoch 59/80, Time: 0.60s, Train Loss: 0.1842, Val Loss: 0.3488, Train Accuracy: 0.9325, Val Accuracy: 0.8738
# Epoch 60/80, Time: 0.55s, Train Loss: 0.1815, Val Loss: 0.3444, Train Accuracy: 0.9333, Val Accuracy: 0.8730
# Epoch 61/80, Time: 0.57s, Train Loss: 0.1789, Val Loss: 0.3369, Train Accuracy: 0.9350, Val Accuracy: 0.8738
# Epoch 62/80, Time: 0.55s, Train Loss: 0.1758, Val Loss: 0.3439, Train Accuracy: 0.9368, Val Accuracy: 0.8738
# Epoch 63/80, Time: 0.57s, Train Loss: 0.1740, Val Loss: 0.3474, Train Accuracy: 0.9372, Val Accuracy: 0.8725
# Epoch 64/80, Time: 0.56s, Train Loss: 0.1701, Val Loss: 0.3482, Train Accuracy: 0.9396, Val Accuracy: 0.8732
# Epoch 65/80, Time: 0.57s, Train Loss: 0.1682, Val Loss: 0.3577, Train Accuracy: 0.9404, Val Accuracy: 0.8738
# Epoch 66/80, Time: 0.56s, Train Loss: 0.1653, Val Loss: 0.3526, Train Accuracy: 0.9411, Val Accuracy: 0.8720
# Epoch 67/80, Time: 0.82s, Train Loss: 0.1623, Val Loss: 0.3501, Train Accuracy: 0.9431, Val Accuracy: 0.8740
# Epoch 68/80, Time: 0.56s, Train Loss: 0.1595, Val Loss: 0.3493, Train Accuracy: 0.9439, Val Accuracy: 0.8720
# Epoch 69/80, Time: 0.55s, Train Loss: 0.1574, Val Loss: 0.3586, Train Accuracy: 0.9442, Val Accuracy: 0.8752
# Epoch 70/80, Time: 0.56s, Train Loss: 0.1539, Val Loss: 0.3699, Train Accuracy: 0.9472, Val Accuracy: 0.8732
# Epoch 71/80, Time: 0.57s, Train Loss: 0.1513, Val Loss: 0.3615, Train Accuracy: 0.9475, Val Accuracy: 0.8722
# Epoch 72/80, Time: 0.57s, Train Loss: 0.1510, Val Loss: 0.3607, Train Accuracy: 0.9474, Val Accuracy: 0.8775
# Epoch 73/80, Time: 0.56s, Train Loss: 0.1475, Val Loss: 0.3499, Train Accuracy: 0.9490, Val Accuracy: 0.8710
# Epoch 74/80, Time: 0.56s, Train Loss: 0.1446, Val Loss: 0.3685, Train Accuracy: 0.9504, Val Accuracy: 0.8720
# Epoch 75/80, Time: 0.56s, Train Loss: 0.1418, Val Loss: 0.3698, Train Accuracy: 0.9516, Val Accuracy: 0.8740
# Epoch 76/80, Time: 0.57s, Train Loss: 0.1392, Val Loss: 0.3715, Train Accuracy: 0.9533, Val Accuracy: 0.8702
# Epoch 77/80, Time: 0.57s, Train Loss: 0.1375, Val Loss: 0.3743, Train Accuracy: 0.9542, Val Accuracy: 0.8698
# Epoch 78/80, Time: 0.57s, Train Loss: 0.1342, Val Loss: 0.3762, Train Accuracy: 0.9560, Val Accuracy: 0.8750
# Epoch 79/80, Time: 0.56s, Train Loss: 0.1336, Val Loss: 0.3670, Train Accuracy: 0.9563, Val Accuracy: 0.8730
# Epoch 80/80, Time: 0.57s, Train Loss: 0.1303, Val Loss: 0.3827, Train Accuracy: 0.9576, Val Accuracy: 0.8722
# Test Accuracy: 0.8730

# %% [markdown]
# ## Adding dropout with probability of 0.4

# %%
class LSTMModel_dropout(nn.Module):
    def __init__(self, embedding_dim, vocab_size, hidden_dim):
        super(LSTMModel_dropout, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.dropout = nn.Dropout(p=0.4)  # Dropout layer with probability 0.2
        self.fc = nn.Linear(hidden_dim, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        embeds = self.embedding(x)
        lstm_out, _ = self.lstm(embeds)
        lstm_out = self.dropout(lstm_out)  # Applying dropout
        lstm_out = lstm_out[:, -1, :]  # Take the output of the last time step
        out = self.fc(lstm_out)
        out = self.sigmoid(out)
        return out.squeeze()

# %% [markdown]
# ## L2 Regularization with weight decay of 1e-3

# %%
# Convert data to PyTorch tensors and move to GPU
x_train_tensor = torch.tensor(x_train).long().to(device)
y_train_tensor = torch.tensor(y_train.values).float().to(device)
x_val_tensor = torch.tensor(x_val).long().to(device)
y_val_tensor = torch.tensor(y_val.values).float().to(device)
x_test_tensor = torch.tensor(x_test).long().to(device)

# Create DataLoader for training and validation sets
train_dataset = TensorDataset(x_train_tensor, y_train_tensor.unsqueeze(1))  # Add unsqueeze(1) to add a singleton dimension
train_loader = DataLoader(train_dataset, batch_size=150, shuffle=True)
val_dataset = TensorDataset(x_val_tensor, y_val_tensor.unsqueeze(1))  # Add unsqueeze(1) to add a singleton dimension
val_loader = DataLoader(val_dataset, batch_size=150)

# Hyperparameters
embedding_dim = 64
hidden_dim = 64
learning_rate = 0.0001
weight_decay = 1e-3  # Weight decay added
num_epochs = 80

# Instantiate the model and move it to GPU
model = LSTMModel_dropout(vocab_size=frequentWord, embedding_dim=embedding_dim, hidden_dim=hidden_dim).to(device)

# Define loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)  # Added weight decay

# Training loop
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(num_epochs):
    start_time = time.time()  # Record start time for the epoch

    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Move batch to GPU
        optimizer.zero_grad()
        outputs = model(inputs)
        labels = labels.view(-1)  # Ensure labels have the correct shape
        loss = criterion(outputs, labels.float())  # Cast labels to float
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)

        predicted = torch.round(outputs)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)
    train_accuracy = correct_train / total_train
    train_accuracies.append(train_accuracy)

    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move batch to GPU
            outputs = model(inputs)
            labels = labels.view(-1)  # Ensure labels have the correct shape
            loss = criterion(outputs, labels.float())  # Cast labels to float
            val_loss += loss.item() * inputs.size(0)

            predicted = torch.round(outputs)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss /= len(val_loader.dataset)
    val_losses.append(val_loss)
    val_accuracy = correct_val / total_val
    val_accuracies.append(val_accuracy)

    epoch_time = time.time() - start_time  # Calculate time taken for the epoch
    print(f'Epoch {epoch+1}/{num_epochs}, Time: {epoch_time:.2f}s, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Accuracy: {val_accuracy:.4f}')


# Plotting train and validation losses
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting train and validation accuracies
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluation on test set
model.eval()
with torch.no_grad():
    outputs = model(x_test_tensor)
    y_pred = torch.round(outputs).cpu().numpy()  # Move predictions to CPU for numpy conversion

# Calculate test accuracy
test_accuracy = np.mean(y_pred == y_test.values)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/80, Time: 1.09s, Train Loss: 0.6908, Val Loss: 0.6880, Train Accuracy: 0.5296, Val Accuracy: 0.5560
# Epoch 2/80, Time: 0.86s, Train Loss: 0.6859, Val Loss: 0.6839, Train Accuracy: 0.5574, Val Accuracy: 0.5615
# Epoch 3/80, Time: 0.84s, Train Loss: 0.6806, Val Loss: 0.6773, Train Accuracy: 0.5764, Val Accuracy: 0.5775
# Epoch 4/80, Time: 0.85s, Train Loss: 0.6587, Val Loss: 0.6289, Train Accuracy: 0.6093, Val Accuracy: 0.6520
# Epoch 5/80, Time: 0.85s, Train Loss: 0.6015, Val Loss: 0.5910, Train Accuracy: 0.6801, Val Accuracy: 0.6883
# Epoch 6/80, Time: 0.85s, Train Loss: 0.5661, Val Loss: 0.5623, Train Accuracy: 0.7141, Val Accuracy: 0.7165
# Epoch 7/80, Time: 0.84s, Train Loss: 0.5316, Val Loss: 0.5190, Train Accuracy: 0.7443, Val Accuracy: 0.7498
# Epoch 8/80, Time: 0.85s, Train Loss: 0.4926, Val Loss: 0.4804, Train Accuracy: 0.7736, Val Accuracy: 0.7735
# Epoch 9/80, Time: 0.83s, Train Loss: 0.4578, Val Loss: 0.4507, Train Accuracy: 0.7955, Val Accuracy: 0.7900
# Epoch 10/80, Time: 0.84s, Train Loss: 0.4366, Val Loss: 0.4392, Train Accuracy: 0.8103, Val Accuracy: 0.7995
# Epoch 11/80, Time: 0.85s, Train Loss: 0.4224, Val Loss: 0.4224, Train Accuracy: 0.8181, Val Accuracy: 0.8070
# Epoch 12/80, Time: 0.85s, Train Loss: 0.4061, Val Loss: 0.4180, Train Accuracy: 0.8256, Val Accuracy: 0.8097
# Epoch 13/80, Time: 0.84s, Train Loss: 0.3981, Val Loss: 0.4063, Train Accuracy: 0.8286, Val Accuracy: 0.8185
# Epoch 14/80, Time: 0.85s, Train Loss: 0.3900, Val Loss: 0.4058, Train Accuracy: 0.8340, Val Accuracy: 0.8183
# Epoch 15/80, Time: 0.83s, Train Loss: 0.3803, Val Loss: 0.4029, Train Accuracy: 0.8383, Val Accuracy: 0.8173
# Epoch 16/80, Time: 0.84s, Train Loss: 0.3740, Val Loss: 0.3945, Train Accuracy: 0.8410, Val Accuracy: 0.8270
# Epoch 17/80, Time: 0.84s, Train Loss: 0.3675, Val Loss: 0.3877, Train Accuracy: 0.8454, Val Accuracy: 0.8270
# Epoch 18/80, Time: 0.84s, Train Loss: 0.3635, Val Loss: 0.3864, Train Accuracy: 0.8479, Val Accuracy: 0.8300
# Epoch 19/80, Time: 0.84s, Train Loss: 0.3586, Val Loss: 0.3893, Train Accuracy: 0.8505, Val Accuracy: 0.8280
# Epoch 20/80, Time: 0.83s, Train Loss: 0.3552, Val Loss: 0.3758, Train Accuracy: 0.8501, Val Accuracy: 0.8340
# Epoch 21/80, Time: 0.83s, Train Loss: 0.3525, Val Loss: 0.3768, Train Accuracy: 0.8528, Val Accuracy: 0.8383
# Epoch 22/80, Time: 0.84s, Train Loss: 0.3473, Val Loss: 0.3713, Train Accuracy: 0.8537, Val Accuracy: 0.8403
# Epoch 23/80, Time: 0.86s, Train Loss: 0.3437, Val Loss: 0.3701, Train Accuracy: 0.8551, Val Accuracy: 0.8390
# Epoch 24/80, Time: 0.84s, Train Loss: 0.3443, Val Loss: 0.3728, Train Accuracy: 0.8561, Val Accuracy: 0.8413
# Epoch 25/80, Time: 0.84s, Train Loss: 0.3363, Val Loss: 0.3673, Train Accuracy: 0.8611, Val Accuracy: 0.8425
# Epoch 26/80, Time: 0.84s, Train Loss: 0.3339, Val Loss: 0.3689, Train Accuracy: 0.8629, Val Accuracy: 0.8415
# Epoch 27/80, Time: 0.84s, Train Loss: 0.3337, Val Loss: 0.3769, Train Accuracy: 0.8613, Val Accuracy: 0.8345
# Epoch 28/80, Time: 0.84s, Train Loss: 0.3295, Val Loss: 0.3718, Train Accuracy: 0.8631, Val Accuracy: 0.8407
# Epoch 29/80, Time: 0.84s, Train Loss: 0.3288, Val Loss: 0.3723, Train Accuracy: 0.8648, Val Accuracy: 0.8393
# Epoch 30/80, Time: 0.85s, Train Loss: 0.3284, Val Loss: 0.3656, Train Accuracy: 0.8648, Val Accuracy: 0.8413
# Epoch 31/80, Time: 0.84s, Train Loss: 0.3218, Val Loss: 0.3558, Train Accuracy: 0.8684, Val Accuracy: 0.8458
# Epoch 32/80, Time: 0.84s, Train Loss: 0.3204, Val Loss: 0.3566, Train Accuracy: 0.8694, Val Accuracy: 0.8468
# Epoch 33/80, Time: 0.83s, Train Loss: 0.3193, Val Loss: 0.3735, Train Accuracy: 0.8697, Val Accuracy: 0.8442
# Epoch 34/80, Time: 0.84s, Train Loss: 0.3150, Val Loss: 0.3617, Train Accuracy: 0.8715, Val Accuracy: 0.8462
# Epoch 35/80, Time: 0.85s, Train Loss: 0.3148, Val Loss: 0.3661, Train Accuracy: 0.8718, Val Accuracy: 0.8452
# Epoch 36/80, Time: 0.84s, Train Loss: 0.3143, Val Loss: 0.3553, Train Accuracy: 0.8728, Val Accuracy: 0.8472
# Epoch 37/80, Time: 0.84s, Train Loss: 0.3115, Val Loss: 0.3609, Train Accuracy: 0.8727, Val Accuracy: 0.8505
# Epoch 38/80, Time: 0.84s, Train Loss: 0.3095, Val Loss: 0.3499, Train Accuracy: 0.8748, Val Accuracy: 0.8480
# Epoch 39/80, Time: 0.85s, Train Loss: 0.3096, Val Loss: 0.3715, Train Accuracy: 0.8739, Val Accuracy: 0.8488
# Epoch 40/80, Time: 0.85s, Train Loss: 0.3079, Val Loss: 0.3608, Train Accuracy: 0.8761, Val Accuracy: 0.8490
# Epoch 41/80, Time: 0.84s, Train Loss: 0.3039, Val Loss: 0.3519, Train Accuracy: 0.8777, Val Accuracy: 0.8488
# Epoch 42/80, Time: 0.83s, Train Loss: 0.3017, Val Loss: 0.3427, Train Accuracy: 0.8784, Val Accuracy: 0.8532
# Epoch 43/80, Time: 0.84s, Train Loss: 0.2974, Val Loss: 0.3652, Train Accuracy: 0.8816, Val Accuracy: 0.8475
# Epoch 44/80, Time: 0.84s, Train Loss: 0.3022, Val Loss: 0.3517, Train Accuracy: 0.8780, Val Accuracy: 0.8460
# Epoch 45/80, Time: 0.84s, Train Loss: 0.2973, Val Loss: 0.3394, Train Accuracy: 0.8779, Val Accuracy: 0.8572
# Epoch 46/80, Time: 0.85s, Train Loss: 0.2946, Val Loss: 0.3381, Train Accuracy: 0.8809, Val Accuracy: 0.8588
# Epoch 47/80, Time: 0.85s, Train Loss: 0.2968, Val Loss: 0.3421, Train Accuracy: 0.8806, Val Accuracy: 0.8528
# Epoch 48/80, Time: 0.84s, Train Loss: 0.2944, Val Loss: 0.3314, Train Accuracy: 0.8836, Val Accuracy: 0.8575
# Epoch 49/80, Time: 0.83s, Train Loss: 0.2932, Val Loss: 0.3443, Train Accuracy: 0.8827, Val Accuracy: 0.8548
# Epoch 50/80, Time: 0.83s, Train Loss: 0.2902, Val Loss: 0.3388, Train Accuracy: 0.8840, Val Accuracy: 0.8600
# Epoch 51/80, Time: 0.84s, Train Loss: 0.2851, Val Loss: 0.3458, Train Accuracy: 0.8874, Val Accuracy: 0.8588
# Epoch 52/80, Time: 0.85s, Train Loss: 0.2868, Val Loss: 0.3405, Train Accuracy: 0.8859, Val Accuracy: 0.8590
# Epoch 53/80, Time: 0.84s, Train Loss: 0.2875, Val Loss: 0.3342, Train Accuracy: 0.8855, Val Accuracy: 0.8605
# Epoch 54/80, Time: 0.84s, Train Loss: 0.2811, Val Loss: 0.3558, Train Accuracy: 0.8897, Val Accuracy: 0.8510
# Epoch 55/80, Time: 0.85s, Train Loss: 0.2816, Val Loss: 0.3275, Train Accuracy: 0.8879, Val Accuracy: 0.8642
# Epoch 56/80, Time: 0.84s, Train Loss: 0.2808, Val Loss: 0.3299, Train Accuracy: 0.8890, Val Accuracy: 0.8658
# Epoch 57/80, Time: 0.86s, Train Loss: 0.2835, Val Loss: 0.3269, Train Accuracy: 0.8874, Val Accuracy: 0.8588
# Epoch 58/80, Time: 0.84s, Train Loss: 0.2768, Val Loss: 0.3327, Train Accuracy: 0.8898, Val Accuracy: 0.8628
# Epoch 59/80, Time: 0.85s, Train Loss: 0.2736, Val Loss: 0.3760, Train Accuracy: 0.8926, Val Accuracy: 0.8323
# Epoch 60/80, Time: 0.83s, Train Loss: 0.2747, Val Loss: 0.3662, Train Accuracy: 0.8919, Val Accuracy: 0.8468
# Epoch 61/80, Time: 0.85s, Train Loss: 0.2730, Val Loss: 0.3579, Train Accuracy: 0.8938, Val Accuracy: 0.8572
# Epoch 62/80, Time: 0.85s, Train Loss: 0.2790, Val Loss: 0.3274, Train Accuracy: 0.8894, Val Accuracy: 0.8650
# Epoch 63/80, Time: 0.86s, Train Loss: 0.2749, Val Loss: 0.3218, Train Accuracy: 0.8923, Val Accuracy: 0.8652
# Epoch 64/80, Time: 0.84s, Train Loss: 0.2730, Val Loss: 0.3302, Train Accuracy: 0.8939, Val Accuracy: 0.8650
# Epoch 65/80, Time: 0.85s, Train Loss: 0.2661, Val Loss: 0.3389, Train Accuracy: 0.8963, Val Accuracy: 0.8625
# Epoch 66/80, Time: 0.84s, Train Loss: 0.2726, Val Loss: 0.3427, Train Accuracy: 0.8911, Val Accuracy: 0.8658
# Epoch 67/80, Time: 0.85s, Train Loss: 0.2626, Val Loss: 0.3175, Train Accuracy: 0.8988, Val Accuracy: 0.8692
# Epoch 68/80, Time: 0.86s, Train Loss: 0.2603, Val Loss: 0.3321, Train Accuracy: 0.8990, Val Accuracy: 0.8630
# Epoch 69/80, Time: 0.86s, Train Loss: 0.2630, Val Loss: 0.3127, Train Accuracy: 0.8976, Val Accuracy: 0.8672
# Epoch 70/80, Time: 0.85s, Train Loss: 0.2632, Val Loss: 0.3135, Train Accuracy: 0.8966, Val Accuracy: 0.8690
# Epoch 71/80, Time: 0.84s, Train Loss: 0.2567, Val Loss: 0.3368, Train Accuracy: 0.9006, Val Accuracy: 0.8558
# Epoch 72/80, Time: 0.83s, Train Loss: 0.2599, Val Loss: 0.3246, Train Accuracy: 0.8993, Val Accuracy: 0.8622
# Epoch 73/80, Time: 0.85s, Train Loss: 0.2572, Val Loss: 0.3315, Train Accuracy: 0.9004, Val Accuracy: 0.8625
# Epoch 74/80, Time: 0.86s, Train Loss: 0.2646, Val Loss: 0.3212, Train Accuracy: 0.8970, Val Accuracy: 0.8672
# Epoch 75/80, Time: 0.83s, Train Loss: 0.2504, Val Loss: 0.3269, Train Accuracy: 0.9030, Val Accuracy: 0.8648
# Epoch 76/80, Time: 0.84s, Train Loss: 0.2519, Val Loss: 0.3389, Train Accuracy: 0.9032, Val Accuracy: 0.8600
# Epoch 77/80, Time: 0.84s, Train Loss: 0.2510, Val Loss: 0.3267, Train Accuracy: 0.9040, Val Accuracy: 0.8640
# Epoch 78/80, Time: 0.85s, Train Loss: 0.2485, Val Loss: 0.3104, Train Accuracy: 0.9029, Val Accuracy: 0.8725
# Epoch 79/80, Time: 0.84s, Train Loss: 0.2487, Val Loss: 0.3394, Train Accuracy: 0.9021, Val Accuracy: 0.8522
# Epoch 80/80, Time: 0.85s, Train Loss: 0.2451, Val Loss: 0.3041, Train Accuracy: 0.9054, Val Accuracy: 0.8718
# Test Accuracy: 0.8670

# %%
### Smoothing out the above graph
import numpy as np
import matplotlib.pyplot as plt

# Define a function for smoothing the data
def smooth_data(data, smoothing_factor=0.9):
    smoothed_data = []
    last_smoothed_point = data[0]
    for point in data:
        smoothed_point = last_smoothed_point * smoothing_factor + point * (1 - smoothing_factor)
        smoothed_data.append(smoothed_point)
        last_smoothed_point = smoothed_point
    return smoothed_data

# Smooth the train and validation losses
smoothed_train_losses = smooth_data(train_losses)
smoothed_val_losses = smooth_data(val_losses)

# Smooth the train and validation accuracies
smoothed_train_accuracies = smooth_data(train_accuracies)
smoothed_val_accuracies = smooth_data(val_accuracies)

# Plotting smoothed train and validation losses
plt.plot(smoothed_train_losses, label='Smoothed Train Loss')
plt.plot(smoothed_val_losses, label='Smoothed Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting smoothed train and validation accuracies
plt.plot(smoothed_train_accuracies, label='Smoothed Train Accuracy')
plt.plot(smoothed_val_accuracies, label='Smoothed Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Calculate test accuracy
test_accuracy = np.mean(y_pred == y_test.values)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Test Accuracy: 0.8670

# %% [markdown]
# ## L2 Regularization with weight decay of 1.3e-3
# # Best Graph
# ## Hyperparameters
# ## Dropout = 0.4
# ## L2 Regularization = 1.3e-3
# ## Batch Size = 150
# ## Learning Rate = 0.0001

# %%
# Convert data to PyTorch tensors and move to GPU
x_train_tensor = torch.tensor(x_train).long().to(device)
y_train_tensor = torch.tensor(y_train.values).float().to(device)
x_val_tensor = torch.tensor(x_val).long().to(device)
y_val_tensor = torch.tensor(y_val.values).float().to(device)
x_test_tensor = torch.tensor(x_test).long().to(device)

# Create DataLoader for training and validation sets
train_dataset = TensorDataset(x_train_tensor, y_train_tensor.unsqueeze(1))  # Add unsqueeze(1) to add a singleton dimension
train_loader = DataLoader(train_dataset, batch_size=150, shuffle=True)
val_dataset = TensorDataset(x_val_tensor, y_val_tensor.unsqueeze(1))  # Add unsqueeze(1) to add a singleton dimension
val_loader = DataLoader(val_dataset, batch_size=150)

# Hyperparameters
embedding_dim = 64
hidden_dim = 64
learning_rate = 0.0001
weight_decay = 1.3e-3  # Weight decay added
num_epochs = 80

# Instantiate the model and move it to GPU
model = LSTMModel_dropout(vocab_size=frequentWord, embedding_dim=embedding_dim, hidden_dim=hidden_dim).to(device)

# Define loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)  # Added weight decay

# Training loop
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(num_epochs):
    start_time = time.time()  # Record start time for the epoch

    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Move batch to GPU
        optimizer.zero_grad()
        outputs = model(inputs)
        labels = labels.view(-1)  # Ensure labels have the correct shape
        loss = criterion(outputs, labels.float())  # Cast labels to float
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)

        predicted = torch.round(outputs)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)
    train_accuracy = correct_train / total_train
    train_accuracies.append(train_accuracy)

    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move batch to GPU
            outputs = model(inputs)
            labels = labels.view(-1)  # Ensure labels have the correct shape
            loss = criterion(outputs, labels.float())  # Cast labels to float
            val_loss += loss.item() * inputs.size(0)

            predicted = torch.round(outputs)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss /= len(val_loader.dataset)
    val_losses.append(val_loss)
    val_accuracy = correct_val / total_val
    val_accuracies.append(val_accuracy)

    epoch_time = time.time() - start_time  # Calculate time taken for the epoch
    print(f'Epoch {epoch+1}/{num_epochs}, Time: {epoch_time:.2f}s, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Accuracy: {val_accuracy:.4f}')


# Plotting train and validation losses
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting train and validation accuracies
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluation on test set
model.eval()
with torch.no_grad():
    outputs = model(x_test_tensor)
    y_pred = torch.round(outputs).cpu().numpy()  # Move predictions to CPU for numpy conversion

# Calculate test accuracy
test_accuracy = np.mean(y_pred == y_test.values)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/80, Time: 1.55s, Train Loss: 0.6941, Val Loss: 0.6896, Train Accuracy: 0.5059, Val Accuracy: 0.5465
# Epoch 2/80, Time: 0.86s, Train Loss: 0.6888, Val Loss: 0.6848, Train Accuracy: 0.5392, Val Accuracy: 0.5640
# Epoch 3/80, Time: 0.86s, Train Loss: 0.6833, Val Loss: 0.6791, Train Accuracy: 0.5662, Val Accuracy: 0.5863
# Epoch 4/80, Time: 0.85s, Train Loss: 0.6755, Val Loss: 0.6643, Train Accuracy: 0.5837, Val Accuracy: 0.6058
# Epoch 5/80, Time: 0.86s, Train Loss: 0.6288, Val Loss: 0.5946, Train Accuracy: 0.6504, Val Accuracy: 0.6837
# Epoch 6/80, Time: 0.85s, Train Loss: 0.5841, Val Loss: 0.5734, Train Accuracy: 0.6981, Val Accuracy: 0.7093
# Epoch 7/80, Time: 0.85s, Train Loss: 0.5567, Val Loss: 0.5440, Train Accuracy: 0.7216, Val Accuracy: 0.7375
# Epoch 8/80, Time: 0.84s, Train Loss: 0.5262, Val Loss: 0.5150, Train Accuracy: 0.7482, Val Accuracy: 0.7558
# Epoch 9/80, Time: 0.87s, Train Loss: 0.4926, Val Loss: 0.4822, Train Accuracy: 0.7750, Val Accuracy: 0.7827
# Epoch 10/80, Time: 0.86s, Train Loss: 0.4639, Val Loss: 0.4643, Train Accuracy: 0.7940, Val Accuracy: 0.7903
# Epoch 11/80, Time: 0.86s, Train Loss: 0.4429, Val Loss: 0.4453, Train Accuracy: 0.8066, Val Accuracy: 0.8100
# Epoch 12/80, Time: 0.85s, Train Loss: 0.4286, Val Loss: 0.4403, Train Accuracy: 0.8154, Val Accuracy: 0.8073
# Epoch 13/80, Time: 0.85s, Train Loss: 0.4173, Val Loss: 0.4235, Train Accuracy: 0.8213, Val Accuracy: 0.8203
# Epoch 14/80, Time: 0.84s, Train Loss: 0.4066, Val Loss: 0.4165, Train Accuracy: 0.8267, Val Accuracy: 0.8200
# Epoch 15/80, Time: 0.86s, Train Loss: 0.3991, Val Loss: 0.4256, Train Accuracy: 0.8298, Val Accuracy: 0.8123
# Epoch 16/80, Time: 0.86s, Train Loss: 0.3920, Val Loss: 0.4125, Train Accuracy: 0.8325, Val Accuracy: 0.8227
# Epoch 17/80, Time: 0.84s, Train Loss: 0.3868, Val Loss: 0.3985, Train Accuracy: 0.8366, Val Accuracy: 0.8275
# Epoch 18/80, Time: 0.83s, Train Loss: 0.3811, Val Loss: 0.3980, Train Accuracy: 0.8397, Val Accuracy: 0.8287
# Epoch 19/80, Time: 0.84s, Train Loss: 0.3746, Val Loss: 0.3894, Train Accuracy: 0.8421, Val Accuracy: 0.8325
# Epoch 20/80, Time: 0.87s, Train Loss: 0.3720, Val Loss: 0.3937, Train Accuracy: 0.8416, Val Accuracy: 0.8300
# Epoch 21/80, Time: 0.87s, Train Loss: 0.3655, Val Loss: 0.3819, Train Accuracy: 0.8461, Val Accuracy: 0.8363
# Epoch 22/80, Time: 0.85s, Train Loss: 0.3610, Val Loss: 0.3841, Train Accuracy: 0.8487, Val Accuracy: 0.8373
# Epoch 23/80, Time: 0.86s, Train Loss: 0.3591, Val Loss: 0.3808, Train Accuracy: 0.8492, Val Accuracy: 0.8387
# Epoch 24/80, Time: 0.85s, Train Loss: 0.3545, Val Loss: 0.3786, Train Accuracy: 0.8529, Val Accuracy: 0.8390
# Epoch 25/80, Time: 0.84s, Train Loss: 0.3516, Val Loss: 0.3754, Train Accuracy: 0.8537, Val Accuracy: 0.8365
# Epoch 26/80, Time: 0.85s, Train Loss: 0.3480, Val Loss: 0.3748, Train Accuracy: 0.8568, Val Accuracy: 0.8405
# Epoch 27/80, Time: 0.85s, Train Loss: 0.3442, Val Loss: 0.3746, Train Accuracy: 0.8578, Val Accuracy: 0.8377
# Epoch 28/80, Time: 0.85s, Train Loss: 0.3427, Val Loss: 0.3667, Train Accuracy: 0.8593, Val Accuracy: 0.8445
# Epoch 29/80, Time: 0.85s, Train Loss: 0.3416, Val Loss: 0.3676, Train Accuracy: 0.8592, Val Accuracy: 0.8395
# Epoch 30/80, Time: 0.83s, Train Loss: 0.3393, Val Loss: 0.3807, Train Accuracy: 0.8615, Val Accuracy: 0.8417
# Epoch 31/80, Time: 0.83s, Train Loss: 0.3366, Val Loss: 0.3603, Train Accuracy: 0.8620, Val Accuracy: 0.8488
# Epoch 32/80, Time: 0.84s, Train Loss: 0.3345, Val Loss: 0.3586, Train Accuracy: 0.8636, Val Accuracy: 0.8472
# Epoch 33/80, Time: 0.86s, Train Loss: 0.3311, Val Loss: 0.3591, Train Accuracy: 0.8653, Val Accuracy: 0.8488
# Epoch 34/80, Time: 0.84s, Train Loss: 0.3305, Val Loss: 0.3563, Train Accuracy: 0.8654, Val Accuracy: 0.8472
# Epoch 35/80, Time: 0.84s, Train Loss: 0.3274, Val Loss: 0.3575, Train Accuracy: 0.8673, Val Accuracy: 0.8490
# Epoch 36/80, Time: 0.84s, Train Loss: 0.3267, Val Loss: 0.3532, Train Accuracy: 0.8678, Val Accuracy: 0.8512
# Epoch 37/80, Time: 0.83s, Train Loss: 0.3237, Val Loss: 0.3613, Train Accuracy: 0.8684, Val Accuracy: 0.8462
# Epoch 38/80, Time: 0.83s, Train Loss: 0.3231, Val Loss: 0.3792, Train Accuracy: 0.8689, Val Accuracy: 0.8390
# Epoch 39/80, Time: 0.84s, Train Loss: 0.3192, Val Loss: 0.3523, Train Accuracy: 0.8709, Val Accuracy: 0.8438
# Epoch 40/80, Time: 0.84s, Train Loss: 0.3183, Val Loss: 0.3606, Train Accuracy: 0.8726, Val Accuracy: 0.8500
# Epoch 41/80, Time: 0.85s, Train Loss: 0.3201, Val Loss: 0.3606, Train Accuracy: 0.8710, Val Accuracy: 0.8515
# Epoch 42/80, Time: 0.85s, Train Loss: 0.3157, Val Loss: 0.3661, Train Accuracy: 0.8736, Val Accuracy: 0.8460
# Epoch 43/80, Time: 0.86s, Train Loss: 0.3141, Val Loss: 0.3505, Train Accuracy: 0.8746, Val Accuracy: 0.8482
# Epoch 44/80, Time: 0.85s, Train Loss: 0.3203, Val Loss: 0.3554, Train Accuracy: 0.8688, Val Accuracy: 0.8528
# Epoch 45/80, Time: 0.85s, Train Loss: 0.3206, Val Loss: 0.3799, Train Accuracy: 0.8674, Val Accuracy: 0.8305
# Epoch 46/80, Time: 0.85s, Train Loss: 0.3159, Val Loss: 0.3427, Train Accuracy: 0.8713, Val Accuracy: 0.8508
# Epoch 47/80, Time: 0.85s, Train Loss: 0.3129, Val Loss: 0.3414, Train Accuracy: 0.8750, Val Accuracy: 0.8545
# Epoch 48/80, Time: 0.87s, Train Loss: 0.3043, Val Loss: 0.3464, Train Accuracy: 0.8793, Val Accuracy: 0.8535
# Epoch 49/80, Time: 0.85s, Train Loss: 0.3092, Val Loss: 0.3519, Train Accuracy: 0.8761, Val Accuracy: 0.8530
# Epoch 50/80, Time: 0.95s, Train Loss: 0.3085, Val Loss: 0.3478, Train Accuracy: 0.8741, Val Accuracy: 0.8580
# Epoch 51/80, Time: 1.01s, Train Loss: 0.3012, Val Loss: 0.3389, Train Accuracy: 0.8798, Val Accuracy: 0.8578
# Epoch 52/80, Time: 0.87s, Train Loss: 0.3038, Val Loss: 0.3439, Train Accuracy: 0.8786, Val Accuracy: 0.8580
# Epoch 53/80, Time: 0.87s, Train Loss: 0.3027, Val Loss: 0.3726, Train Accuracy: 0.8783, Val Accuracy: 0.8320
# Epoch 54/80, Time: 0.92s, Train Loss: 0.3022, Val Loss: 0.3553, Train Accuracy: 0.8788, Val Accuracy: 0.8550
# Epoch 55/80, Time: 0.90s, Train Loss: 0.3003, Val Loss: 0.3446, Train Accuracy: 0.8801, Val Accuracy: 0.8572
# Epoch 56/80, Time: 0.90s, Train Loss: 0.2981, Val Loss: 0.3431, Train Accuracy: 0.8821, Val Accuracy: 0.8528
# Epoch 57/80, Time: 0.89s, Train Loss: 0.2964, Val Loss: 0.3528, Train Accuracy: 0.8836, Val Accuracy: 0.8545
# Epoch 58/80, Time: 0.91s, Train Loss: 0.2926, Val Loss: 0.3430, Train Accuracy: 0.8843, Val Accuracy: 0.8532
# Epoch 59/80, Time: 0.90s, Train Loss: 0.2956, Val Loss: 0.3314, Train Accuracy: 0.8828, Val Accuracy: 0.8620
# Epoch 60/80, Time: 0.91s, Train Loss: 0.2934, Val Loss: 0.3279, Train Accuracy: 0.8857, Val Accuracy: 0.8605
# Epoch 61/80, Time: 0.89s, Train Loss: 0.2889, Val Loss: 0.3416, Train Accuracy: 0.8881, Val Accuracy: 0.8582
# Epoch 62/80, Time: 0.87s, Train Loss: 0.2915, Val Loss: 0.3705, Train Accuracy: 0.8838, Val Accuracy: 0.8440
# Epoch 63/80, Time: 0.88s, Train Loss: 0.2923, Val Loss: 0.3373, Train Accuracy: 0.8841, Val Accuracy: 0.8618
# Epoch 64/80, Time: 0.89s, Train Loss: 0.2841, Val Loss: 0.3202, Train Accuracy: 0.8873, Val Accuracy: 0.8655
# Epoch 65/80, Time: 0.90s, Train Loss: 0.2872, Val Loss: 0.3308, Train Accuracy: 0.8874, Val Accuracy: 0.8610
# Epoch 66/80, Time: 0.86s, Train Loss: 0.2789, Val Loss: 0.3407, Train Accuracy: 0.8920, Val Accuracy: 0.8615
# Epoch 67/80, Time: 0.86s, Train Loss: 0.2860, Val Loss: 0.3280, Train Accuracy: 0.8879, Val Accuracy: 0.8670
# Epoch 68/80, Time: 0.88s, Train Loss: 0.2801, Val Loss: 0.3156, Train Accuracy: 0.8898, Val Accuracy: 0.8678
# Epoch 69/80, Time: 0.89s, Train Loss: 0.2734, Val Loss: 0.3285, Train Accuracy: 0.8944, Val Accuracy: 0.8642
# Epoch 70/80, Time: 0.86s, Train Loss: 0.2766, Val Loss: 0.3143, Train Accuracy: 0.8915, Val Accuracy: 0.8672
# Epoch 71/80, Time: 0.85s, Train Loss: 0.2820, Val Loss: 0.3196, Train Accuracy: 0.8902, Val Accuracy: 0.8630
# Epoch 72/80, Time: 0.86s, Train Loss: 0.2740, Val Loss: 0.3799, Train Accuracy: 0.8923, Val Accuracy: 0.8350
# Epoch 73/80, Time: 0.86s, Train Loss: 0.2814, Val Loss: 0.3223, Train Accuracy: 0.8895, Val Accuracy: 0.8702
# Epoch 74/80, Time: 0.88s, Train Loss: 0.2714, Val Loss: 0.3402, Train Accuracy: 0.8934, Val Accuracy: 0.8530
# Epoch 75/80, Time: 0.90s, Train Loss: 0.2716, Val Loss: 0.3181, Train Accuracy: 0.8946, Val Accuracy: 0.8655
# Epoch 76/80, Time: 0.88s, Train Loss: 0.2705, Val Loss: 0.3149, Train Accuracy: 0.8954, Val Accuracy: 0.8688
# Epoch 77/80, Time: 0.86s, Train Loss: 0.2610, Val Loss: 0.3133, Train Accuracy: 0.8999, Val Accuracy: 0.8705
# Epoch 78/80, Time: 0.87s, Train Loss: 0.2641, Val Loss: 0.3259, Train Accuracy: 0.8978, Val Accuracy: 0.8655
# Epoch 79/80, Time: 0.87s, Train Loss: 0.2610, Val Loss: 0.3165, Train Accuracy: 0.8993, Val Accuracy: 0.8642
# Epoch 80/80, Time: 0.88s, Train Loss: 0.2639, Val Loss: 0.3200, Train Accuracy: 0.8969, Val Accuracy: 0.8680
# Test Accuracy: 0.8673

# %%
### Smoothing out the above graph
import numpy as np
import matplotlib.pyplot as plt

# Define a function for smoothing the data
def smooth_data(data, smoothing_factor=0.9):
    smoothed_data = []
    last_smoothed_point = data[0]
    for point in data:
        smoothed_point = last_smoothed_point * smoothing_factor + point * (1 - smoothing_factor)
        smoothed_data.append(smoothed_point)
        last_smoothed_point = smoothed_point
    return smoothed_data

# Smooth the train and validation losses
smoothed_train_losses = smooth_data(train_losses)
smoothed_val_losses = smooth_data(val_losses)

# Smooth the train and validation accuracies
smoothed_train_accuracies = smooth_data(train_accuracies)
smoothed_val_accuracies = smooth_data(val_accuracies)

# Plotting smoothed train and validation losses
plt.plot(smoothed_train_losses, label='Smoothed Train Loss')
plt.plot(smoothed_val_losses, label='Smoothed Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting smoothed train and validation accuracies
plt.plot(smoothed_train_accuracies, label='Smoothed Train Accuracy')
plt.plot(smoothed_val_accuracies, label='Smoothed Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Calculate test accuracy
test_accuracy = np.mean(y_pred == y_test.values)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Test Accuracy: 0.8673
